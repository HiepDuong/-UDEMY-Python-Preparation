# %% [markdown]
# ## Using plot.hist(), plot.bar()
# ## Using plot(kind = ' ')
# ## Mostly use panda this with histogram
#
#  ### Simplicity and Convenience + Useful for Quick Exploration:
# - With just a single line of code,
#  ### Variety of Plotting Options:
# - Pandas provides a variety of plotting methods, including line, bar, histogram, scatter, etc., making it versatile for a variety of visual tasks.
#  ## For fully customisation use matplotlib and sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
df1 = pd.read_csv('df1', index_col= 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
#generate column A histogram
df1['A'].hist(bins =30)
# Out:
# <Axes: >

# %%
#plot using plot with kind = ''
df1['A'].plot(kind = 'hist', bins = 30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Using plot.hist()
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked =True)
#can use stacl
# x is index and y is value
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(y='B', figsize =(12,3),  lw =1)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x= 'A', y= 'B', c= 'C', cmap = 'coolwarm')
#using column A as x axis, B as y axis,
# C is the value in each coordiante
#use color c argument
# can use size s
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x= 'A', y= 'B', s =df1['C']*100)
#use color c argument
# can use size s
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -1.320334 -2.725777
# 1 -0.829052  0.899850
# 2  0.103478 -1.191323
# 3  0.418882 -0.165228
# 4 -0.699079  0.360209

# %%
df.plot.hexbin(x='a',y='b', gridsize= 25, cmap ='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>
