# %% [markdown]
# # df.iplot(kind = ' ') to make plot interactive
# # if using bar, can use aggregate function
#  - df.count.iplot(kind ='bar')
#
# # 3d array with surface plot
# # iplot(kind = 'spread')
# # bubble plot : kind = 'bubble, use for GDP or united nation report
# # df.scatter_matrix()

# %%
import pandas as pd
import numpy as np
from plotly import __version__
print (__version__)
# %matplotlib inline
# Out:
# 5.9.0

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected= True)
#connect javascript to note book
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# allow to use cufflink offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4), columns= 'A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.054699 -1.233137 -0.472595 -0.603911
# 1  0.297866  1.254787  0.010053  1.629888
# 2  1.418516  0.191932 -0.445033  1.845217
# 3  0.387839 -0.265056  0.072915 -1.074495
# 4  0.254176 -0.394962  0.357831 -0.241283

# %%
df2 = pd.DataFrame({'Category': ['A','B','C'], 'Values': [32,43,50]})

# %%
df.iplot()  #
# Out:
# <div>                            <div id="1c71e5cc-a3a5-46d5-8edd-47cdd71fd4e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter', x = 'A', y ='B', mode = 'markers', size= 20)
#use mode = markers because plotly connect all the dot
# Out:
# <div>                            <div id="1b45c208-e367-4c8a-8013-648248f59855" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter', x = 'A', y ='B')
# Out:
# <div>                            <div id="936b391c-7dae-4f49-951e-4170ca48f699" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind = 'bar', x= 'Category', y = 'Values')
# Out:
# <div>                            <div id="bb7cb192-fc58-42be-ac52-33d718b5bba9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind = 'bar')
# Out:
# <div>                            <div id="697e61ac-d54b-46d9-a510-374c5f9ab6b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot('box')
# Out:
# <div>                            <div id="89b98076-cc89-4853-9a7c-fc32bce3a920" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # 3D surface plot

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.iplot(kind = 'surface', colorscale = 'RDYLBU')
# Out:
# <div>                            <div id="4f5b273f-357e-488f-8297-be13f845c09e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind = 'hist', bins = 25)
# Out:
# <div>                            <div id="c60c5fd4-b3f5-4e95-9a50-672a67cf3f96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'hist', bins = 25)
# Out:
# <div>                            <div id="f5a64229-09bb-4869-8886-e41a5a689a16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# #  Spread plot

# %%
df[['A','B']].iplot(kind = 'spread')
# Out:
# C:\Users\ACER\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\ACER\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="71b5cf66-a947-47b1-98b2-b17b41f5ca71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Bubble Plot

# %%
df.iplot(kind = 'bubble',x ='A', y ='B', size = 'C')
# Out:
# <div>                            <div id="ad4c79ee-55d3-424a-84b0-18a6033fc2ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # scatter_matrix

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="25a83d2b-7d8d-43a4-81ff-c82a85314a74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
